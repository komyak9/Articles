# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data/Weather_dataset.csv")
df.time = pd.to_datetime(df.time)
df.head()
# Out:
#                  time  temperature  relative_humidity  dew_point  \
# 0 2000-01-01 00:00:00         -0.1                 97       -0.5
# 1 2000-01-01 01:00:00         -0.2                 97       -0.7
# 2 2000-01-01 02:00:00         -0.1                 96       -0.6
# 3 2000-01-01 03:00:00         -0.2                 96       -0.7
# 4 2000-01-01 04:00:00         -0.2                 96       -0.8
#
#    precipitation (mm)  rain (mm)  snowfall (cm)  pressure_msl (hPa)  \
# 0                 0.0        0.0            0.0              1024.2
# 1                 0.0        0.0            0.0              1024.4
# 2                 0.0        0.0            0.0              1024.5
# 3                 0.0        0.0            0.0              1024.2
# 4                 0.0        0.0            0.0              1024.0
#
#    surface_pressure (hPa)  cloud_cover (%)  cloud_cover_low (%)  \
# 0                  1019.3               87                   76
# 1                  1019.5               89                   79
# 2                  1019.6              100                   89
# 3                  1019.3              100                   92
# 4                  1019.1              100                   76
#
#    cloud_cover_mid (%)  cloud_cover_high (%)  vapour_pressure_deficit (kPa)  \
# 0                    3                    56                           0.02
# 1                    1                    58                           0.02
# 2                    9                    80                           0.02
# 3                   34                    92                           0.02
# 4                   51                    98                           0.02
#
#    wind_speed_10m (km/h)  wind_direction
# 0                    5.9             169
# 1                    5.8             173
# 2                    6.1             180
# 3                    6.8             183
# 4                    6.8             183
